# %%
import numpy as np
import matplotlib.pyplot as plt

# Função U(x) = x^4 - x^2 e seu gradiente
def U_new(x):
    return x**4 - x**2

def dU_new_dx(x):
    return 4 * x**3 - 2 * x

# Gradiente descendente adaptado para a nova função
x=1.2 #ponto inicial
tax_alfa=0.1
num_inter= 100
tolerancia= 0.01
x_valor= [x]
y_valor=[U_new(x)]

for i in range (num_inter):
    gradiente = dU_new_dx(x)
    x_novo = x - tax_alfa * gradiente
    x_valor.append(x_novo)
    y_valor.append(U_new(x_novo))

    if abs(x_novo - x) < tolerancia:
        break
    x= x_novo

min_x = x
max_x = U_new(min_x)
print(f"\n o valor mínimo aproximado é: x=(min_x)")
print(f"\n o valor mínimo aproximado é: y=(min_y)")


# Curva da função
x_vals = np.linspace(-2, 2, 500)
y_vals = U_new(x_vals)

# Plotando os resultados
plt.figure(figsize=(12, 8))
plt.plot(x_vals, y_vals, label='U(x) = x⁴ - x²', color='black')

colors = ['red', 'green', 'blue', 'orange', 'purple']
for alpha, color in zip(alphas, colors):
    traj = np.array(trajectories[alpha])
    plt.plot(traj, U_new(traj), marker='o', linestyle='-', color=color, label=f'α = {alpha}')

plt.title('Trajetória do gradiente descendente na função U(x) = x⁴ - x²')
plt.xlabel('x')
plt.ylabel('U(x)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#  o valor mínimo aproximado é: x=(min_x)
#
#  o valor mínimo aproximado é: y=(min_y)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 44
#      41 plt.plot(x_vals, y_vals, label='U(x) = x⁴ - x²', color='black')
#      43 colors = ['red', 'green', 'blue', 'orange', 'purple']
# ---> 44 for alpha, color in zip(alphas, colors):
#      45     traj = np.array(trajectories[alpha])
#      46     plt.plot(traj, U_new(traj), marker='o', linestyle='-', color=color, label=f'α = {alpha}')
#
# NameError: name 'alphas' is not defined
